# %% [markdown]
# <a href="https://colab.research.google.com/github/YazeedAsmar/Python/blob/master/Data%20Analysis/Level%200/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Project: Retail Store Sales & Customer Feedback Analyzer
#
# Welcome to this practical project. You will apply your Python knowledge to analyze data from a hypothetical retail store. This project aims to strengthen your skills in handling data structures, loops, functions, and the Pandas library to provide actionable business insights.

# %% [markdown]
# ### Phase 1: Data Initialization (Dictionaries & Lists)
# In this phase, we represent the store's products using Dictionaries and the sales history using Lists. Your task is to access specific data points using keys and slicing operations.

# %%
# Phase 1: Data Initialization

# Dictionary of products and their prices
inventory = {
    "Laptop": 1200,
    "Mouse": 25,
    "Keyboard": 45,
    "Monitor": 150,
    "USB-C Cable": 15
}

# List of sales transactions (amounts in USD) for the first 7 days
weekly_sales = [1200, 450, 900, 150, 600, 1100, 300]

# TODO: 1. Print the price of the 'Monitor' using the dictionary key
# TODO: 2. Create a new list called 'midweek_sales' using slicing for days 3, 4, and 5

print("Monitor Price:")
# Write your code here

print("Mid-week Sales:")
# Write your code here
# Out:
# Monitor Price:
# Mid-week Sales:

# %% [markdown]
# ### Phase 2: Sales Filtering (Loops & Conditionals)
# We will now process a monthly sales list. The goal is to calculate the total revenue and identify days where sales did not meet the target to issue performance warnings.

# %%
# Phase 2: Sales Filtering

sales_target = 500
monthly_sales = [400, 600, 750, 300, 900, 150, 1100, 480, 520, 610]

total_revenue = 0
low_sales_days = 0

# TODO: Loop through monthly_sales to:
# 1. Calculate the total_revenue
# 2. Check if a daily sale is below the sales_target
# 3. If below target, print a warning and increment low_sales_days

# Write your loop here

print(f"Total Monthly Revenue: {total_revenue}")
print(f"Number of days below target: {low_sales_days}")

# %% [markdown]
# ### Phase 3: Business Logic (Functions)
# Instead of repeating calculations, you will create a reusable function that calculates the final price of a product after adding tax and applying a discount.

# %%
# Phase 3: Business Logic (Functions)

def apply_discount_and_tax(price, discount_rate=0.10, tax_rate=0.05):
    """
    Calculates final price after discount and tax.
    Default discount is 10%, Default tax is 5%.
    """
    # TODO: Calculate discounted_price
    # TODO: Add tax to the discounted_price
    # TODO: Return final_price
    pass

# TODO: Test your function with a price of 1000 and a 20% discount
# final_amount = apply_discount_and_tax(1000, 0.20)
# print(f"Final Price: {final_amount}")

# %% [markdown]
# ### Phase 4: Security Access (While Loop)
# To protect sensitive reports, we will program a simple login system that requires a PIN code. You will grant the user 3 attempts before locking the system.

# %%
# Phase 4: Security Access

SECRET_PIN = "1234"
attempts = 0
max_attempts = 3
locked = True

# TODO: Use a while loop to ask the user for input()
# 1. Compare input with SECRET_PIN
# 2. If correct, set locked = False and 'break'
# 3. If wrong, increment attempts and print remaining tries

while attempts < max_attempts:
    # Write your security logic here
    pass

if not locked:
    print("Access Granted. Generating Report...")
else:
    print("Access Denied. System Locked.")

# %% [markdown]
# ### Phase 5: Statistical Report (Pandas & Math)
# In the final phase, we use the Pandas library to analyze a full month (30 days) of sales data. We will calculate the Mean, Median, Mode, and Standard Deviation to present a professional summary to management.

# %%
# Phase 5: Statistical Report
import pandas as pd

# List of sales for 30 days
daily_sales_data = [
    550, 600, 450, 700, 800, 300, 400, 900, 1000, 1200,
    450, 500, 550, 600, 700, 750, 800, 900, 1000, 1100,
    300, 350, 400, 450, 500, 550, 600, 650, 700, 1500
]

# TODO: 1. Convert daily_sales_data list into a pandas DataFrame named 'df'
# TODO: 2. Calculate Mean, Median, Mode, and Standard Deviation using pandas methods

# df = pd.DataFrame(daily_sales_data, columns=['Sales'])

print("--- Business Summary Report ---")
# print(f"Mean Sales: {df['Sales'].mean()}")
# TODO: Complete the statistical summary print statements in English
